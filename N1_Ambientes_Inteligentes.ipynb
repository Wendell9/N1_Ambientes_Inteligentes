# %% [markdown]
# <a href="https://colab.research.google.com/github/Wendell9/N1_Ambientes_Inteligentes/blob/main/N1_Ambientes_Inteligentes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aluno: Wendell Moreira Guindani
# RA: 082220017

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %% [markdown]
# # **1. Explorando o Dataset**
#
#
# Dataset de filmes recomendados para educação e desenvolvimento, conforme o link abaixo:
#
# https://files.grouplens.org/datasets/movielens/ml-latest-small.zip

# %%
links = pd.read_csv('content/links.csv')
movies = pd.read_csv('content/movies.csv')
ratings = pd.read_csv('content/ratings.csv')
tags = pd.read_csv('content/tags.csv')

# %% [markdown]
# # **Questão 1**

# %% [markdown]
# # Informações Gerais do Dataset

# %%
print(f'O dataset links possui {links.shape[0]} linhas e {links.shape[1]} colunas.')
print(f'O dataset movies possui {movies.shape[0]} linhas e {movies.shape[1]} colunas.')
print(f'O dataset ratings possui {ratings.shape[0]} linhas e {ratings.shape[1]} colunas.')
print(f'O dataset tags possui {tags.shape[0]} linhas e {tags.shape[1]} colunas.')
# Out:
# O dataset links possui 9742 linhas e 3 colunas.
# O dataset movies possui 9742 linhas e 3 colunas.
# O dataset ratings possui 100836 linhas e 4 colunas.
# O dataset tags possui 3683 linhas e 4 colunas.

# %%
links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   imdbId   9742 non-null   int64
#  2   tmdbId   9734 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 228.5 KB

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3683 non-null   int64
#  1   movieId    3683 non-null   int64
#  2   tag        3683 non-null   object
#  3   timestamp  3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB

# %%
links.describe()
# Out:
#              movieId        imdbId         tmdbId
# count    9742.000000  9.742000e+03    9734.000000
# mean    42200.353623  6.771839e+05   55162.123793
# std     52160.494854  1.107228e+06   93653.481487
# min         1.000000  4.170000e+02       2.000000
# 25%      3248.250000  9.518075e+04    9665.500000
# 50%      7300.000000  1.672605e+05   16529.000000
# 75%     76232.000000  8.055685e+05   44205.750000
# max    193609.000000  8.391976e+06  525662.000000

# %%
movies.describe()
# Out:
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
tags.describe()
# Out:
#             userId        movieId     timestamp
# count  3683.000000    3683.000000  3.683000e+03
# mean    431.149335   27252.013576  1.320032e+09
# std     158.472553   43490.558803  1.721025e+08
# min       2.000000       1.000000  1.137179e+09
# 25%     424.000000    1262.500000  1.137521e+09
# 50%     474.000000    4454.000000  1.269833e+09
# 75%     477.000000   39263.000000  1.498457e+09
# max     610.000000  193565.000000  1.537099e+09

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# No dataset acima cada linha contem o id do filme, o titulo e o genero do respectivo filme

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# No dataset acima cada linha contem o id do filme, o id no imdb e um identificador de filmes usado no site https://www.themoviedb.org

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# No dataset acima cada linha contem o id do usuario(userId), id do filme(movieId), nota do filme(rating) e timestamp representa os segundos desde a meia noite a partir de 01 de janeiro de 1970, a partir desse dado é possível obter a data em que a critica o usuario deu aquela nota para o filme.

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %% [markdown]
# No dataset acima cada linha contem o id do usuário(userId), o id do filme(movieId), uma tag que o usuário associou ao filme(tag), e a data que ele fez isso no formato timestamp(número de segundos decorrente desde meia noite de 1° de janeiro de 1970)

# %% [markdown]
# ## Questão 2

# %%
ratings.rename(columns={'timestamp':'dateTime'}, inplace=True)
ratings['dateTime'] = pd.to_datetime(ratings['dateTime'], unit='s')

tags.rename(columns={'timestamp':'dateTime'}, inplace=True)
tags['dateTime'] = pd.to_datetime(tags['dateTime'], unit='s')

# %%
ratings.head(100)
# Out:
#     userId  movieId  rating            dateTime
# 0        1        1     4.0 2000-07-30 18:45:03
# 1        1        3     4.0 2000-07-30 18:20:47
# 2        1        6     4.0 2000-07-30 18:37:04
# 3        1       47     5.0 2000-07-30 19:03:35
# 4        1       50     5.0 2000-07-30 18:48:51
# ..     ...      ...     ...                 ...
# 95       1     1445     3.0 2000-07-30 19:08:32
# 96       1     1473     4.0 2000-07-30 18:14:35
# 97       1     1500     4.0 2000-07-30 18:16:25
# 98       1     1517     5.0 2000-07-30 18:18:27
# 99       1     1552     4.0 2000-07-30 18:43:40
#
# [100 rows x 4 columns]

# %%
tags.head(100)
# Out:
#     userId  movieId              tag            dateTime
# 0        2    60756            funny 2015-10-24 19:29:54
# 1        2    60756  Highly quotable 2015-10-24 19:29:56
# 2        2    60756     will ferrell 2015-10-24 19:29:52
# 3        2    89774     Boxing story 2015-10-24 19:33:27
# 4        2    89774              MMA 2015-10-24 19:33:20
# ..     ...      ...              ...                 ...
# 95      62     6541     captain nemo 2018-05-05 21:00:54
# 96      62     6541       comic book 2018-05-05 21:00:28
# 97      62     6541           gothic 2018-05-05 21:00:56
# 98      62     6541      Peta Wilson 2018-05-05 21:00:40
# 99      62     6541     Sean Connery 2018-05-05 21:00:26
#
# [100 rows x 4 columns]

# %% [markdown]
# Para melhor vizualização dos dados as datas que estavam no formato timestamp foram convertidas para o formato DateTime.

# %%
links.columns = ['IdFilme', 'IdImdb', 'Idtmdb']
movies.columns = ['IdFilme', 'Titulo', 'Genero']
ratings.columns = ['IdUsuario', 'IdFilme', 'Nota', 'Data']
tags.columns = ['IdUsuario', 'IdFilme', 'Tag', 'Data']

# %%
links.head(100)
# Out:
#     IdFilme  IdImdb   Idtmdb
# 0         1  114709    862.0
# 1         2  113497   8844.0
# 2         3  113228  15602.0
# 3         4  114885  31357.0
# 4         5  113041  11862.0
# ..      ...     ...      ...
# 95      107  117110  10874.0
# 96      108  112646  89333.0
# 97      110  112573    197.0
# 98      111   75314    103.0
# 99      112  113326  33542.0
#
# [100 rows x 3 columns]

# %%
movies.head(100)
# Out:
#     IdFilme                                      Titulo  \
# 0         1                            Toy Story (1995)
# 1         2                              Jumanji (1995)
# 2         3                     Grumpier Old Men (1995)
# 3         4                    Waiting to Exhale (1995)
# 4         5          Father of the Bride Part II (1995)
# ..      ...                                         ...
# 95      107               Muppet Treasure Island (1996)
# 96      108                              Catwalk (1996)
# 97      110                           Braveheart (1995)
# 98      111                          Taxi Driver (1976)
# 99      112  Rumble in the Bronx (Hont faan kui) (1995)
#
#                                          Genero
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 2                                Comedy|Romance
# 3                          Comedy|Drama|Romance
# ...

# %%
ratings.head(100)
# Out:
#     IdUsuario  IdFilme  Nota            DateTime
# 0           1        1   4.0 2000-07-30 18:45:03
# 1           1        3   4.0 2000-07-30 18:20:47
# 2           1        6   4.0 2000-07-30 18:37:04
# 3           1       47   5.0 2000-07-30 19:03:35
# 4           1       50   5.0 2000-07-30 18:48:51
# ..        ...      ...   ...                 ...
# 95          1     1445   3.0 2000-07-30 19:08:32
# 96          1     1473   4.0 2000-07-30 18:14:35
# 97          1     1500   4.0 2000-07-30 18:16:25
# 98          1     1517   5.0 2000-07-30 18:18:27
# 99          1     1552   4.0 2000-07-30 18:43:40
#
# [100 rows x 4 columns]

# %%
tags.head(100)
# Out:
#     IdUsuario  IdFilme              Tag            DateTime
# 0           2    60756            funny 2015-10-24 19:29:54
# 1           2    60756  Highly quotable 2015-10-24 19:29:56
# 2           2    60756     will ferrell 2015-10-24 19:29:52
# 3           2    89774     Boxing story 2015-10-24 19:33:27
# 4           2    89774              MMA 2015-10-24 19:33:20
# ..        ...      ...              ...                 ...
# 95         62     6541     captain nemo 2018-05-05 21:00:54
# 96         62     6541       comic book 2018-05-05 21:00:28
# 97         62     6541           gothic 2018-05-05 21:00:56
# 98         62     6541      Peta Wilson 2018-05-05 21:00:40
# 99         62     6541     Sean Connery 2018-05-05 21:00:26
#
# [100 rows x 4 columns]

# %% [markdown]
# Para facilitar a leitura dos dados foi realizado uma tradução no nome da coluna de todas as tabelas.

# %%
links[links["Idtmdb"].isnull()]
# Out:
#       IdFilme  IdImdb  Idtmdb
# 624       791  113610     NaN
# 843      1107  102336     NaN
# 2141     2851   81454     NaN
# 3027     4051   56600     NaN
# 5532    26587   92337     NaN
# 5854    32600  377059     NaN
# 6059    40697  105946     NaN
# 7382    79299  874957     NaN

# %% [markdown]
# É possível ver que em 8 linhas a tabela links tem o Idtmdb nulo. Uma maneira de corrigir isso é removendo essas linhas caso apliquemos algum filtro que leve em consideração apenas filmes que tenham um Idtmdb.

# %%
links = links.dropna(subset=['Idtmdb'])

# %%
links[links["Idtmdb"].isnull()]
# Out:
# Empty DataFrame
# Columns: [IdFilme, IdImdb, Idtmdb]
# Index: []
